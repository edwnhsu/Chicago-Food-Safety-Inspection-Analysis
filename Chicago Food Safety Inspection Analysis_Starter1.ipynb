# %% [markdown]
# ### Assignment 1 Starter Code
# **Note:** your records counts will be different, depending on when you query the API

# %%
import pandas as pd
import requests

# %%
# %%time

# Define the API endpoint and parameters
url = "https://data.cityofchicago.org/resource/cwig-ma7x.json"

# Fetch the total count of records
def get_total_count(url):
    params = {
        "$select": "count(*)"
    }
    response = requests.get(url, params=params)
    data = response.json()
    return int(data[0]['count'])

total_count = get_total_count(url)
print(f"Total number of records available: {total_count:,.0f}")
# Out:
# Total number of records available: 252,386
# CPU times: user 40.7 ms, sys: 726 µs, total: 41.4 ms
# Wall time: 694 ms

# %%
# %%time

# Fetch data and load it into a pandas DataFrame
def fetch_data(url, params):
    response = requests.get(url, params=params)
    data = response.json()
    return pd.DataFrame(data)

# Set the limit parameter equal to the number of available records
params = {
    "$limit": total_count
}

# Fetch the data and load it into a DataFrame
df = fetch_data(url, params)

print(f'Number of records retrieved: {df.shape[0]:,.0f}')
# Out:
# Number of records retrieved: 252,386
# CPU times: user 9.32 s, sys: 1.57 s, total: 10.9 s
# Wall time: 38.8 s

# %%
df.head(5)
# Out:
#   inspection_id                              dba_name  \
# 0       2574172  J + L FAMILY LEARNING DAYCARE CENTER
# 1       2574195                   NEW PARADISE BAKERY
# 2       2574182          JOE & THE JUICE NEW YORK LLC
# 3       2574187               LITTLE GREEN TREE HOUSE
# 4       2574196                          TACOS EL REY
#
#                                aka_name license_  \
# 0  J + L FAMILY LEARNING DAYCARE CENTER  2220707
# 1                   NEW PARADISE BAKERY  2831624
# 2                       JOE & THE JUICE  2578419
# 3               LITTLE GREEN TREE HOUSE  2216214
# 4                          TACOS EL REY  2900956
#
#                      facility_type           risk  \
# 0  Daycare Above and Under 2 Years  Risk 1 (High)
# 1                           Bakery  Risk 1 (High)
# 2                              NaN  Risk 1 (High)
# 3     Children's Services Facility  Risk 1 (High)
# 4                       Restaurant   Risk 3 (Low)
#
#                         address     city state    zip  ...  \
# 0  11638-11640 S WENTWORTH AVE   CHICAGO    IL  60628  ...
# 1    5742-5744 N MILWAUKEE AVE   CHICAGO    IL  60630  ...
# 2               412 N WELLS ST   CHICAGO    IL  60654  ...
# 3           3111 N ASHLAND AVE   CHICAGO    IL  60657  ...
# 4             9625 S EWING AVE   CHICAGO    IL  60617  ...
#
#               results                                         violations  \
# 0                Pass  47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE...
# 1                Fail  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...
# 2                Fail  2. CITY OF CHICAGO FOOD SERVICE SANITATION CER...
# 3  Pass w/ Conditions  1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...
# 4                Pass                                                NaN
#
#              latitude           longitude  \
# 0   41.68225833336412  -87.62773601885556
# 1   41.98580160371477  -87.77716403422917
# 2  41.889647025824154  -87.63416925556209
# 3  41.938253305553516  -87.66846320182256
# 4  41.720590461950856  -87.53514240131703
#
#                                             location  \
# 0  {'type': 'Point', 'coordinates': [-87.62773601...
# 1  {'type': 'Point', 'coordinates': [-87.77716403...
# 2  {'type': 'Point', 'coordinates': [-87.63416925...
# 3  {'type': 'Point', 'coordinates': [-87.66846320...
# 4  {'type': 'Point', 'coordinates': [-87.53514240...
#
#   :@computed_region_awaf_s7ux :@computed_region_6mkv_f3dw  \
# 0                          45                       21861
# 1                          20                       22532
# 2                          22                        4446
# 3                          16                        4449
# 4                          47                       21202
#
#   :@computed_region_vrxf_vc4k :@computed_region_bdys_3d7i  \
# 0                          50                         255
# 1                          11                         701
# 2                          37                         652
# 3                          57                         712
# 4                          49                         705
#
#   :@computed_region_43wa_7qmu
# 0                          22
# 1                          50
# 2                          36
# 3                          40
# 4                          47
#
# [5 rows x 22 columns]
